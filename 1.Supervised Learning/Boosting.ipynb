# %% [markdown]
# # <u>Boosting</u>
#
# ### Prerequisites:
#
# * <a href="../1.Supervised Learning/1.Regression/">Check out the notebookes on Regression</a>
# * <a href="../1.Supervised Learning/2.Classification/">Check out the notebooks on Classification</a>
#
# ## Topics
#
# * [1. What is Boosting?](#what)
# * [2. Boosting vs. Bagging](#vs)
# * [3. Adaptive Boosting (AdaBoost)](#ada)
# * [4. Forward Stagewise Additive Modeling](#forward)
# * [5. Gradient Boosting](#gradient)
# * [6. Regularization in Gradient Boosting](#reg)
# * [7. Stochastic Gradient Boosting](#stochastic)
# * [8. Gradient Boosting for Classification](#class)
# * [9. Multiclass Gradient Boosting](#multi)
# * [10. Gradient Boosting with Trees](#trees)
# * [11. XGBoost (Extreme Gradient Boosting)](#xg)
# * [12. XGBoost Regularization](#xg_reg)
# * [13. Important XGBoost Hyperparameters](#xg_hyper)
# * [14. Key Takeaways](#takeaway)

# %%
import numpy as np # for arrays and random numbers
import matplotlib.pyplot as plt # for plotting
from sklearn.tree import DecisionTreeClassifier # for Classification Trees
from sklearn.tree import DecisionTreeRegressor # for Regression Trees
from sklearn.ensemble import RandomForestClassifier # Random Forest Classifier
from sklearn.ensemble import RandomForestRegressor # Random Forest Regressor

from sklearn.datasets import make_classification # toy data for classification
from sklearn.datasets import make_regression # toy data for regression

print("Setup complete")
# Out:
# Setup complete

# %% [markdown]
# <a class="anchor" id="what"></a>
# # 1. What is Boosting?

# %% [markdown]
# <a class="anchor" id="vs"></a>
# # 2. Boosting vs. Bagging

# %% [markdown]
# <a class="anchor" id="ada"></a>
# # 3. Adaptive Boosting (AdaBoost)

# %% [markdown]
# <a class="anchor" id="forward"></a>
# # 4. Forward Stagewise Additive Modeling

# %% [markdown]
# <a class="anchor" id="gradient"></a>
# # 5. Gradient Boosting

# %% [markdown]
# <a class="anchor" id="reg"></a>
# # 6. Regularization in Gradient Boosting

# %% [markdown]
# <a class="anchor" id="stochastic"></a>
# # 7. Stochastic Gradient Boosting

# %% [markdown]
# <a class="anchor" id="class"></a>
# # 8. Gradient Boosting for Classification

# %% [markdown]
# <a class="anchor" id="multi"></a>
# # 9. Multiclass Gradient Boosting

# %% [markdown]
# <a class="anchor" id="trees"></a>
# # 10. Gradient Boosting with Trees

# %% [markdown]
# <a class="anchor" id="xg"></a>
# # 11. XGBoost (Extreme Gradient Boosting)

# %% [markdown]
# <a class="anchor" id="xg_reg"></a>
# # 12. XGBoost Regularization

# %% [markdown]
# <a class="anchor" id="xg_hyper"></a>
# # 13. Important XGBoost Hyperparameters

# %% [markdown]
# <a class="anchor" id="takeaway"></a>
# # 14. Key Takeaways
