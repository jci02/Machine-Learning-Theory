# %% [markdown]
# # <u>Random Forest Classification</u>
#
# ### Prerequisites:
# * <a href="../../2.Classification/6.Descision Trees Classifier/Descision Trees Classifier.ipynb">Check out the notebook on Decision Tree Classifier</a>
#
#
# ## Topics
#
# * [1. Core idea](#idea)
#
#
# * [6. Splitting criteria](#split)
#     * [**6.1 Regression**](#reg)
#     * [6.2 Classification](#class)
#         * <a href="../../1.Regression/8.Random Forest Regression/Random Forest.ipynb">Check out the notebook on Random Forest Regression</a>
#
# * [7. Handling Features](#features)

# %%
import numpy as np # for rnadom number, linear algebra and general mathematical operations
import pandas as pd # for creating and working with dataframe
from matplotlib import pyplot as plt # for plotting in 2d
import plotly.express as px # for plotting in 3d
import plotly.graph_objects as go # for plotting in 3d
from sklearn.tree import DecisionTreeClassifier # for Classification trees
from sklearn.tree import plot_tree # to plot trees
from sklearn.tree import export_text # export tree rules
from sklearn.impute import SimpleImputer # for replacing missing values
from sklearn.datasets import make_blobs # to create toy data for classification
from sklearn.ensemble import RandomForestClassifier # for Random Forest CLassifier
print("Setup complete")
# Out:
# Setup complete
