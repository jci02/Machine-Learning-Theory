# %% [markdown]
# # <u>SVM-Nonlinear case</u>
#
# ### Prerequisites:
# * <a href="../8.Support Vector Machines/Support Vector Machines-Linear case.ipynb">Check out the notebook on Support Vector Machines-Linear case</a>
#
#
#
# ## Topics
#
# * [1. Core idea](#idea)
